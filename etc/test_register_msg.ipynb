# %%
from register_msg import register
from register_msg import register_trading_msg
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /home/kimp_bot_core/etc/test_register_msg.ipynb Cell 1 in <cell line: 2>()
#       <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f6b705f74726164655f76325f646576222c2273657474696e6773223a7b22686f7374223a227373683a2f2f434f524532227d7d/home/kimp_bot_core/etc/test_register_msg.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> from register_msg import register
# ----> <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f6b705f74726164655f76325f646576222c2273657474696e6773223a7b22686f7374223a227373683a2f2f434f524532227d7d/home/kimp_bot_core/etc/test_register_msg.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> from register_msg import register_trading_msg
#
# ...

# %%
# register("5556345865:AAFJy8wdyTjKxDBOb89bTRFsNs6UFMn4twY", "http://222.106.173.213:22180/api/monitor_v1/monitorbot/", 'test', 'test_type','test_title', 'test_contnet')
