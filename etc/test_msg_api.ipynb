# %%
import datetime
import pandas as pd
import requests
import os
import sys
from msg_api import MsgApi

# %%
message_api = MsgApi(prod=False)

# acw_api.create_message(telegram_chat_id=1390695186, title="test_from_core3_trade_core", origin="test", type="info", content="test", remark="test", code=None, sent=False, send_times=1, send_term=1)
message_api.get_message()
# Out:
# /usr/local/lib/python3.9/site-packages/urllib3/connectionpool.py:1095: InsecureRequestWarning: Unverified HTTPS request is being made to host 'acw-dev.orbitholdings.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
#     id                  datetime telegram_bot_username  telegram_chat_id  \
# 0    1  2023-12-26T13:05:12+0000          test_acw_bot        1722781031
# 1    2  2024-01-08T09:20:58+0000          test_acw_bot        1722781031
# 2    3  2024-01-09T09:05:21+0000    arbicrypto_dev_bot        1722781031
# 3    4  2024-01-09T09:05:21+0000    arbicrypto_dev_bot        1390695186
# 4    5  2024-01-09T09:05:21+0000    arbicrypto_dev_bot        1731633310
# 5    6  2024-01-09T09:13:40+0000    arbicrypto_dev_bot        1722781031
# 6    7  2024-01-09T09:13:40+0000    arbicrypto_dev_bot        1390695186
# ...

# %%
message_api.delete_message(17)
message_api.get_message()
# Out:
# /usr/local/lib/python3.9/site-packages/urllib3/connectionpool.py:1095: InsecureRequestWarning: Unverified HTTPS request is being made to host 'acw-dev.orbitholdings.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/urllib3/connectionpool.py:1095: InsecureRequestWarning: Unverified HTTPS request is being made to host 'acw-dev.orbitholdings.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
#     id                  datetime telegram_bot_username  telegram_chat_id  \
# 0    1  2023-12-26T13:05:12+0000          test_acw_bot        1722781031
# 1    2  2024-01-08T09:20:58+0000          test_acw_bot        1722781031
# 2    3  2024-01-09T09:05:21+0000    arbicrypto_dev_bot        1722781031
# ...

# %%
message_api.get_message()
# Out:
# /usr/local/lib/python3.9/site-packages/urllib3/connectionpool.py:1095: InsecureRequestWarning: Unverified HTTPS request is being made to host 'acw-dev.orbitholdings.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
#     id                  datetime telegram_bot_username  telegram_chat_id  \
# 0    1  2023-12-26T13:05:12+0000          test_acw_bot        1722781031
# 1    2  2024-01-08T09:20:58+0000          test_acw_bot        1722781031
# 2    3  2024-01-09T09:05:21+0000    arbicrypto_dev_bot        1722781031
# 3    4  2024-01-09T09:05:21+0000    arbicrypto_dev_bot        1390695186
# 4    5  2024-01-09T09:05:21+0000    arbicrypto_dev_bot        1731633310
# 5    6  2024-01-09T09:13:40+0000    arbicrypto_dev_bot        1722781031
# 6    7  2024-01-09T09:13:40+0000    arbicrypto_dev_bot        1390695186
# ...

# %%
message_api.delete_message(16)
# Out:
# /usr/local/lib/python3.9/site-packages/urllib3/connectionpool.py:1095: InsecureRequestWarning: Unverified HTTPS request is being made to host 'acw-dev.orbitholdings.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 message_api.delete_message(16)
#
# Input In [1], in Message_API.delete_message(self, id)
#      54     return True
#      55 else:
# ---> 56     raise Exception("Error: " + str(response.status_code) + "\n" + response.text)
#
# Exception: Error: 404
# {"detail":"Not found."}
