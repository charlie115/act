# %%
from command_handler import CommandHandler

node = 'trade_core_dev'
admin_telegram_id = 1390695186
core = 

command_handler = CommandHandler(node, admin_telegram_id, core, logging_dir)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 from command_handler import CommandHandler
#       3 command_handler = CommandHandler()
#
# File /home/trade_core/etc/command_handler.py:6, in <module>
#       4 import os
#       5 import traceback
# ----> 6 from loggers.logger import KimpBotLogger
#       8 class CommandHandler:
#       9     def __init__(self, node, admin_telegram_id, core, logging_dir):
#
# ModuleNotFoundError: No module named 'loggers'

# %%
command_handler = CommandHandler('trade_core_dev', 1390695186, None)

# %%
command_handler.fetch_command()
# Out:
# /usr/local/lib/python3.9/site-packages/urllib3/connectionpool.py:1095: InsecureRequestWarning: Unverified HTTPS request is being made to host 'acw-test.orbitholdings.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/urllib3/connectionpool.py:1095: InsecureRequestWarning: Unverified HTTPS request is being made to host 'acw-test.orbitholdings.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# restart executed!
# kill: usage: kill [-s sigspec | -n signum | -sigspec] pid | jobspec ... or kill -l [sigspec]
# ...

# %%
command_message_df
# Out:
#       id                  datetime telegram_bot_username  telegram_chat_id  \
# 0  60855  2024-05-30T10:41:07+0000    arbicrypto_dev_bot                 0
# 1  60854  2024-05-30T10:41:04+0000    arbicrypto_dev_bot                 0
#
#             title content remarks             origin     type  code  sent  \
# 0  trade_core_dev    test    None  ceo@halo-soft.net  COMMAND  None  True
# 1  trade_core_dev  status    None  ceo@halo-soft.net  COMMAND  None  True
#
#    send_times  send_term   read
# 0           1          1  False
# 1           1          1  False
