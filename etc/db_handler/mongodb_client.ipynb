# %%
import os
import sys
import pymongo
# upper_dir = os.path.dirname(os.path.dirname(os.path.abspath(__file__)))
upper_dir = '/home/info_core' # TEST
sys.path.append(upper_dir)
from loggers.logger import KimpBotLogger


class InitDBClient:
    def __init__(self, host, port, user, passwd, logging_dir=None):
        self.logger = None
        self.host = host
        self.port = port
        self.username = user
        
        self.password = passwd
        self.uri = f"mongodb://{user}:{passwd}@{host}:{port}/"
        if logging_dir is not None:
            self.logger = KimpBotLogger("InitDBClient", logging_dir).logger

    def get_conn(self):
        mongo_client = pymongo.MongoClient(self.uri)
        return mongo_client

# %%
db_client = InitDBClient(host='14.52.68.128', port=27017, user='test', passwd='CommunityMongodb123!')

# %%
client = db_client.get_conn()
client
# Out:
# MongoClient(host=['14.52.68.128:27017'], document_class=dict, tz_aware=False, connect=True)

# %%
client.list_database_names()
# Out:
# ['ACW_USER_CHAT',
#  'BINANCE_fundingrate',
#  'BITHUMB_SPOT__KRW-BINANCE_USD_M__USDT',
#  'BITHUMB_SPOT__KRW-OKX_USD_M__USDT',
#  'BYBIT_fundingrate',
#  'OKX_fundingrate',
#  'UPBIT_SPOT__KRW-BINANCE_USD_M__USDT',
#  'admin',
#  'arbitrage_fundingrate',
#  'config',
#  'local',
#  'wallet_status']

# %%
client.close()
