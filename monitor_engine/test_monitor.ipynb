# %%
import pandas as pd
import pymysql
import datetime

# Connect to DB
def connect_db(database, host, port, user, passwd):
    conn = pymysql.connect(
        host = host,
        port = port,
        user = user,
        passwd = passwd,
        database = database
    )
    curr = conn.cursor(pymysql.cursors.DictCursor)
    return conn,curr

remote_db_dict = {"host":"222.106.173.216","port":22153,"user":"root","passwd":"13245dh!!"}

# %%
class InitTest:
    def __init__(self):
        self.test1 = 'test1'
        self.test_list1 = []
        self.test_dict1 = {'a': 1}
    
class InitTest2:
    def __init__(self, input_str, input_list, input_dict):
        self.input_str = input_str
        self.input_list = input_list
        self.input_dict = input_dict

    def change_input_str(self, str_to_change):
        self.input_str = str_to_change
    
    def append_input_list(self, element_to_append):
        self.input_list.append(element_to_append)

    def mutate_input_dict(self, key_value_tuple):
        self.input_dict[key_value_tuple[0]] = key_value_tuple[1]
