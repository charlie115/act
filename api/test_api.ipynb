# %%
from sqlalchemy.orm import Session
import sys
import os
sys.path.append('/home/trade_core/api')
import models, schemas, database
import pandas as pd
import datetime
import time
import requests
from pprint import pprint
import uuid

# %%
prod_domain_url = 'http://221.148.128.205:20081/'
dev_domain_url = 'http://127.0.0.1:8080/'
target_endpoint = 'spot-balance/'
res = requests.get(dev_domain_url + 'trade-config/')
print(f"code: {res.status_code}\ncontent: {res.content}")
test_acw_user_uuid = '11724593-caed-49b8-ba1f-99c74589db7e'
# Out:
# code: 200
# content: b'[{"uuid":"80f911ae-d4dc-4483-a141-01ed143dce8e","acw_user_uuid":"50bb7048-cb9c-4461-b737-7e106d8ee455","referral_code":null,"telegram_id":1722781031,"send_times":1,"send_term":1,"registered_datetime":"2024-02-02T11:12:52.028804","service_datetime_end":"2024-02-02T11:12:52.028815","target_market_code":"UPBIT_SPOT/KRW","origin_market_code":"BITHUMB_SPOT/KRW","target_market_uid":null,"origin_market_uid":null,"target_market_referral_use":false,"origin_market_referral_use":false,"target_market_cross":false,"target_market_leverage":null,"origin_market_cross":false,"origin_market_leverage":null,"target_market_margin_call":null,"origin_market_margin_call":null,"target_market_safe_reverse":false,"origin_market_safe_reverse":false,"target_market_risk_threshold_p":null,"origin_market_risk_threshold_p":null,"repeat_limit_p":null,"repeat_limit_direction":null,"repeat_num_limit":null,"on_off":false,"remark":null,"id":42},{"uuid":"407a5369-fd79-4b82-82e6-24360436c60d","acw_user_uuid":"50bb7048-cb9c-4461-b737-7e106d8ee455","referral_code":null,"telegram_id":1722781031,"send_times":1,"send_term":1,"registered_datetime":"2024-02-02T11:16:30.360290","service_datetime_end":"2024-02-02T11:16:30.360298","target_market_code":"UPBIT_SPOT/KRW","origin_market_code":"UPBIT_SPOT/BTC","target_market_uid":null,"origin_market_uid":null,"target_market_referral_use":false,"origin_market_referral_use":false,"target_market_cross":false,"target_market_leverage":null,"origin_market_cross":false,"origin_market_leverage":null,"target_market_margin_call":null,"origin_market_margin_call":null,"target_market_safe_reverse":false,"origin_market_safe_reverse":false,"target_market_risk_threshold_p":null,"origin_market_risk_threshold_p":null,"repeat_limit_p":null,"repeat_limit_direction":null,"repeat_num_limit":null,"on_off":false,"remark":null,"id":43},{"uuid":"00dc872d-b31d-412d-94e5-9de9026f4a48","acw_user_uuid":"87c2c8da-ad4d-47d5-adbd-7aec629000dc","referral_code":null,"telegram_id":1722781031,"send_times":1,"send_term":1,"registered_datetime":"2024-02-05T03:03:35.349344","service_datetime_end":"2024-02-05T03:03:35.349363","target_market_code":"UPBIT_SPOT/KRW","origin_market_code":"BINANCE_USD_M/USDT","target_market_uid":null,"origin_market_uid":null,"target_market_referral_use":false,"origin_market_referral_use":false,"target_market_cross":false,"target_market_leverage":null,"origin_market_cross":false,"origin_market_leverage":null,"target_market_margin_call":null,"origin_market_margin_call":null,"target_market_safe_reverse":false,"origin_market_safe_reverse":false,"target_market_risk_threshold_p":null,"origin_market_risk_threshold_p":null,"repeat_limit_p":null,"repeat_limit_direction":null,"repeat_num_limit":null,"on_off":false,"remark":null,"id":44},{"uuid":"650137a7-b554-4e57-ac95-208d8eb6e864","acw_user_uuid":"3fa85f64-5717-4562-b3fc-2c963f66afa6","referral_code":null,"telegram_id":0,"send_times":1,"send_term":1,"registered_datetime":"2024-02-02T04:22:38.866879","service_datetime_end":null,"target_market_code":"string","origin_market_code":"string","target_market_uid":null,"origin_market_uid":null,"target_market_referral_use":null,"origin_market_referral_use":null,"target_market_cross":null,"target_market_leverage":null,"origin_market_cross":null,"origin_market_leverage":null,"target_market_margin_call":null,"origin_market_margin_call":null,"target_market_safe_reverse":null,"origin_market_safe_reverse":null,"target_market_risk_threshold_p":null,"origin_market_risk_threshold_p":null,"repeat_limit_p":null,"repeat_limit_direction":null,"repeat_num_limit":null,"on_off":true,"remark":null,"id":32},{"uuid":"82ab3d97-5765-44d3-9b9a-5f52c8dfbd33","acw_user_uuid":"3fa85f64-5717-4562-b3fc-2c963f66afa6","referral_code":null,"telegram_id":0,"send_times":1,"send_term":1,"registered_datetime":"2024-02-02T04:23:31.345079","service_datetime_end":null,"target_market_code":"UPBIT_SPOT/KRW","origin_market_code":"UPBIT_SPOT/BTC","target_market_uid":null,"origin_market_uid ...

# %%
res = requests.get(dev_domain_url + target_endpoint)
if res.status_code == 200:
    pprint(res.json())
else:
    print(f"code: {res.status_code}\ncontent: {res.content}")
# Out:
# code: 404
# content: b'{"detail":"Not Found"}'

# %%
params = {
    "market_code": "UPBIT_SPOT/KRW",
}
res = requests.get(dev_domain_url + target_endpoint + "d1b3f6e0-5b9e-4b0e-8b0a-9f6f5f5e0b1a", params=params)
if res.status_code == 200:
    pprint(res.json())
else:
    print(f"code: {res.status_code}\ncontent: {res.content}")
# Out:
# [{'asset': 'KRW', 'free': 42679379.67839748, 'locked': 0.0},
#  {'asset': 'ETH', 'free': 4e-08, 'locked': 0.0},
#  {'asset': 'XRP', 'free': 11321.00000003, 'locked': 0.0},
#  {'asset': 'ETC', 'free': 311.6, 'locked': 0.0},
#  {'asset': 'WAVES', 'free': 1e-08, 'locked': 0.0},
#  {'asset': 'LSK', 'free': 2442.0, 'locked': 0.0},
#  {'asset': 'ARK', 'free': 3e-08, 'locked': 0.0},
#  {'asset': 'BCH', 'free': 2e-08, 'locked': 0.0},
#  {'asset': 'STORJ', 'free': 1e-08, 'locked': 0.0},
#  {'asset': 'USDT', 'free': 0.05839856, 'locked': 0.0},
#  {'asset': 'WAXP', 'free': 1e-08, 'locked': 0.0},
#  {'asset': 'POLYX', 'free': 2e-08, 'locked': 0.0},
#  {'asset': 'GAS', 'free': 543.0, 'locked': 0.0},
#  {'asset': 'HIFI', 'free': 5575.00000001, 'locked': 0.0},
#  {'asset': 'ORBS', 'free': 1e-08, 'locked': 0.0},
#  {'asset': 'STX', 'free': 4944.00000002, 'locked': 0.0},
#  {'asset': 'AAVE', 'free': 1e-08, 'locked': 0.0},
#  {'asset': 'APENFT', 'free': 516.50802691, 'locked': 0.0},
#  {'asset': 'SOL', 'free': 42.0, 'locked': 0.0},
#  {'asset': 'QI', 'free': 1.62935972, 'locked': 0.0},
#  {'asset': 'IMX', 'free': 1e-08, 'locked': 0.0},
#  {'asset': 'GMT', 'free': 15175.00000001, 'locked': 0.0},
#  {'asset': 'BLUR', 'free': 3e-08, 'locked': 0.0},
#  {'asset': 'SEI', 'free': 14718.00000002, 'locked': 0.0}]

# %%
params = {
    "acw_user_uuid": test_acw_user_uuid,
}
res = requests.get(dev_domain_url + target_endpoint + 'ceee4931-e36b-45e4-9106-a3ecfa0aedc1', params=None)
if res.status_code == 200:
    pprint(res.json())
else:
    print(f"code: {res.status_code}\ncontent: {res.content}")
# Out:
# code: 404
# content: b'{"detail":"Exchange api key not found"}'

# %%
params = {
    "acw_user_uuid": test_acw_user_uuid,
}
res = requests.delete(dev_domain_url + target_endpoint, params=params)
print(res.status_code)
# Out:
# 405

# %%
res = requests.delete(dev_domain_url + target_endpoint + '')
print(res.status_code)

# %%
trade_config_body = {
    # "acw_user_uuid": test_acw_user_uuid,
    # "acw_user_uuid": "test_uuid",
    # "telegram_id": 1390695186,
    # "send_times": 1,
    "send_term": 2,
    # "registered_datetime": None,
    # "service_datetime_end": "2024-02-24T12:30:46",
    # "target_market_code": "UPBIT_SPOT/KRW",
    # "origin_market_code": "BINANCE_USD_M/USDT",
    # "target_market_uid": None,
    # "origin_market_uid": None,
    # "target_market_referral_use": None,
    # "origin_market_referral_use": None,
    # "target_market_cross": None,
    # "target_market_leverage": None,
    # "origin_market_cross": None,
    # "origin_market_leverage": None,
    # "target_market_margin_call": None,
    # "origin_market_margin_call": None,
    # "target_market_safe_reverse": None,
    # "origin_market_safe_reverse": None,
    # "target_market_risk_threshold_p": None,
    # "origin_market_risk_threshold_p": None,
    # "repeat_limit_p": None,
    # "repeat_limit_direction": None,
    # "repeat_num_limit": None,
    # "on_off": True,
    # "remark": "string"
}

trade_body = {
  "trade_config_uuid": "57f5df1d-95f9-49eb-b7e4-c15042c9b59f",
  "base_asset": "XRP",
  "usdt_conversion": False,
  "low": 3.232,
  "high": 4.42324,
}

exchange_api_key_body = {
    "trade_config_uuid": "57f5df1d-95f9-49eb-b7e4-c15042c9b59f",
    "market_code": "UPBIT_SPOT/KRW",
    "access_key": "x2AKLfsRtAgRxFjQ7p9TZTAg6E1SveoqfNfD8MK8",
    "secret_key": "svEran52QdsUyJdxAPYoTgFT2MXsHc5ZiKsKPxTL",
}

# res = requests.post(dev_domain_url + target_endpoint, json=exchange_api_key_body)
res = requests.post(dev_domain_url + "exchange-api-key", json=exchange_api_key_body)
print(f"code: {res.status_code}")
pprint(res.json())
# Out:
# code: 409
# {'detail': 'Exchange api key already exists'}

# %%
trade_config_body = {
    "acw_user_uuid": test_acw_user_uuid,
    # "acw_user_uuid": "test_uuid",
    "telegram_id": 1390695186,
    # "send_times": 1,
    # "send_term": 1,
    # "registered_datetime": None,
    "service_datetime_end": "2024-02-24T12:30:46",
    "target_market_code": "UPBIT_SPOT/KRW",
    "origin_market_code": "BINANCE_USD_M/USDT",
    # "target_market_uid": None,
    # "origin_market_uid": None,
    # "target_market_referral_use": None,
    # "origin_market_referral_use": None,
    # "target_market_cross": None,
    # "target_market_leverage": None,
    # "origin_market_cross": None,
    # "origin_market_leverage": None,
    # "target_market_margin_call": None,
    # "origin_market_margin_call": None,
    # "target_market_safe_reverse": None,
    # "origin_market_safe_reverse": None,
    # "target_market_risk_threshold_p": None,
    # "origin_market_risk_threshold_p": None,
    # "repeat_limit_p": None,
    # "repeat_limit_direction": None,
    # "repeat_num_limit": None,
    # "on_off": True,
    # "remark": "string"
}

trade_body = {
  # "user_uuid": "a264b28a-1e05-4671-90b0-fa200e0a3539",
  # "base_asset": "BTC",
  # "usdt_conversion": True,
  # "target_market_code": "UPBIT_SPOT/KRW",
  # "origin_market_code": "BINANCE_USD_M/USDT",
  "low": 5,
  # "high": 7,
  # "status": "ok",
  # "uuid": "59448e69-00f6-43cc-9e0f-7f6eb2eeeb33"
}

res = requests.put(dev_domain_url + target_endpoint + 'f514ebf9-e1d4-496c-a25d-6d9940d85132', json=trade_body)
print(f"code: {res.status_code}")
pprint(res.json())
# Out:
# code: 200
# {'base_asset': 'BTC',
#  'enter_origin_market_order_id': None,
#  'enter_target_market_order_id': None,
#  'exit_origin_market_order_id': None,
#  'exit_target_market_order_id': None,
#  'high': 7.0,
#  'id': 17,
#  'last_updated_datetime': '2024-02-02T09:16:24.854042',
#  'low': 5.0,
#  'registered_datetime': '2024-02-02T09:01:03.773749',
#  'remark': None,
#  'status': None,
#  'trade_capital': None,
#  'trade_config_uuid': 'e060c86a-4745-492c-a912-5f496edbda63',
#  'trade_switch': None,
#  'trigger_switch': None,
#  'usdt_conversion': False,
#  'uuid': 'f514ebf9-e1d4-496c-a25d-6d9940d85132'}
